# %%
import requests 
import urllib.request 
from bs4 import BeautifulSoup 
import os

# %%
url = "https://mail.google.com/mail/u/0/?pli=1"#search/in%3Asent+jeudi+nsi

# %%
requete = requests.get(url)
soup = BeautifulSoup(requete.text, "html.parser")
div = soup.findAll("div")

# %%
div = soup.findAll("div")
print(len(div))
# Out:
# 0

# %%
for ligne in div:
    print(ligne)
# Out:
# <div class="BDEI9 LZgQXe"><div class="Ha17qf" data-auto-init="Card"><div class="Or16q"><div data-allow-sign-up-types="true" data-locale="en_US" data-view-id="hm18Ec"><c-wiz c-wiz="" data-node-index="2;0" data-p="%.@.]" jsdata="deferred-i2" jsmodel="hc6Ubd" jsrenderer="OTcFib" jsshadow=""><div class="gEc4r"><img alt="Google" class="TrZEUc" height="24" src="//ssl.gstatic.com/images/branding/googlelogo/2x/googlelogo_color_74x24dp.png" width="74"/></div><c-data id="i2" jsdata=" eCjdDd;_;3"></c-data></c-wiz><div class="EQIoSc" jsname="bN97Pc"><div jsname="paFcre"><div class="aMfydd" jsname="tJHJj"><h1 class="Tn0LBd" jsname="r4nke">Sign in</h1><p class="a2CQh" jsname="VdSJob">to continue to Gmail</p></div></div><form action="/v3/signin/identifier?continue=https://mail.google.com/mail/u/0/?pli%3D1&amp;dsh=S486768850:1682330612488587&amp;emr=1&amp;flowEntry=ServiceLogin&amp;flowName=WebLiteSignIn&amp;followup=https://mail.google.com/mail/u/0/?pli%3D1&amp;ifkv=AQMjQ7Qw_0hjyh0JZE_LYUhtslknpAgv
# ...

# %%
for ligne in div:
    print("id" in ligne )
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Untitled-1.ipynb Cellule 7 in 3
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=0'>1</a> table = soup.find('div', attrs = {'id':'livescore'})
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=1'>2</a> compt = 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=2'>3</a> for row in table.findAll('div', attrs = {'class':'panel panel-info'}):
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=3'>4</a>                 print(row)
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %%
for id in div:
    if id.findChild() is not None:
        print(id.findChild().text.strip())
# Out:
# Sign into continue to GmailEmail or phoneForgot email?Not your computer? Use a private browsing window to sign in. Learn moreNextCreate account
# Sign into continue to GmailEmail or phoneForgot email?Not your computer? Use a private browsing window to sign in. Learn moreNextCreate account
# Sign into continue to GmailEmail or phoneForgot email?Not your computer? Use a private browsing window to sign in. Learn moreNextCreate account
#
#
# Sign into continue to Gmail
# Sign into continue to Gmail
# Sign in
# Email or phoneForgot email?
# Email or phone
# Email or phone
# Email or phone
# Email or phone
# Email or phone
#
# Not your computer? Use a private browsing window to sign in. Learn more
# NextCreate account
# Next
# Next
# Create account
# ...
